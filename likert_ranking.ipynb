# %%
import plot_likert
import pandas as pd

df = pd.read_csv('data/dashboard-export-02-51-am-2024-11-30.csv')
print(df.columns)

likely_scale = ['Very unlikely ',
     'Unlikely ',
     'Neutral ',
     'Likely ',
     'Very likely ']

important_scale = ['Not at all important', 
                   'Not important',
                   'Neutral', 
                   'Important',
                   'Very important']

plot_likert.__internal__.BAR_LABEL_FORMAT = "%.0f"

# plot_likert.plot_likert(df['Q5 - If these types of technologies were made available to the community, how li...'], likely_scale, plot_percentage=True, bar_labels=True, bar_labels_color="snow", colors=plot_likert.colors.default_with_darker_neutral);

# Define the column range using the start and end column names
start_column = 'Q7 - Technology should be accessible and help people feel included, safe, and co...'
end_column = 'Q11 - Technology should drive business growth and education opportunities, creati...'

# Use .loc to slice the dataframe by column names
for column in df.loc[:, start_column:end_column].columns:
    plot_likert.plot_likert(df[column], important_scale, plot_percentage=True, bar_labels=True, bar_labels_color="snow", colors=plot_likert.colors.default_with_darker_neutral);
# Out:
# Index(['Survey Metadata - Start Date (+00:00 GMT)',
#        'Survey Metadata - End Date (+00:00 GMT)',
#        'Survey Metadata - Response Type', 'Survey Metadata - IP Address',
#        'Survey Metadata - Progress', 'Survey Metadata - Duration (in seconds)',
#        'Survey Metadata - Finished',
#        'Survey Metadata - Recorded Date (+00:00 GMT)',
#        'Contact Fields - Recipient Last Name',
#        'Contact Fields - Recipient First Name',
#        'Contact Fields - Recipient Email',
#        'Contact Fields - External Reference',
#        'Survey Metadata - Location Latitude',
#        'Survey Metadata - Location Longitude',
#        'Contact Fields - Distribution Channel',
#        'Survey Metadata - User Language', 'Embedded Data - Q_RecaptchaScore',
#        'Q1_Browser - Browser', 'Q1_Version - Version',
#        'Q1_Operating System - Operating System', 'Q1_Resolution - Resolution',
#        'Q3 - We already have some council provided community technology in place. Which...',
#        'Q4 - What technology would you like to see more of in our community? *\n\nPlease t...',
#        'Q4_11_TEXT - Other, please specify.',
#        'Q5 - If these types of technologies were made available to the community, how li...',
#        'Q7 - Technology should be accessible and help people feel included, safe, and co...',
#        'Q8 - Technology should help preserve and protect our environment and make counci...',
#        'Q9 - Technology should enable council to plan thriving town centres, resilient i...',
#        'Q10 - Technology should make it easy to move around our city and use sustainable...',
#        'Q11 - Technology should drive business growth and education opportunities, creati...',
#        'Q13 - Traffic congestion. *', 'Q14 - A revitalised city centre. *',
#        'Q15 - Reliable and timely public transport. *',
#        'Q16 - Public safety. *', 'Q17 - Visibility of available parking. *',
#        'Q18 - Staying informed and providing feedback on council decisions. *',
#        'Q19 - Other, please specify',
#        'Q20 - How important is this issue to you?',
#        'Q21_1 - Roads, footpaths, and cycle ways. ',
#        'Q21_4 - Rubbish and recycling services. ',
#        'Q21_5 - Building and planning. ',
#        'Q21_6 - Outdoor spaces, such as parks. ',
#        'Q21_7 - Public facilities, such as community centres.  ',
#        'Q21_8 - Drinking water, wastewater, and stormwater services. ',
#        'Q21_9 - Business licensing and compliance. ',
#        'Q21_10 - Community services, such as events. ',
#        'Q21_11 - Other, please specify', 'Q21_11_TEXT - Other, please specify',
#        'Q22 - Is there anything preventing you from using technology in our community’s o...',
#        'Q22_10_TEXT - Other, please specify.',
#        'Q23 - Do you have any ideas for new technology or examples you've seen from other...',
#        'Q24 - Do you have any other feedback or comments you would like to make about cou...',
#        'Q25 - How would you rate your digital skills when using community technology? *...',
#        'Q26 - Age: *', 'Q27 - Gender: *',
#        'Q27_6_TEXT - Other (please specify)',
#        'Q28 - The University of Waikato and Tauranga City Council are undertakinga resear...',
#        'Q29 - First name: *', 'Q30 - Last name: *', 'Q31 - Email: *',
#        'Q32 - Phone: *', 'Q34 - Sign up to stay informed',
#        'Embedded Data - utm_source', 'Embedded Data - utm_campaign',
#        'Embedded Data - utm_medium', 'Embedded Data - utm_content',
#        'Embedded Data - Q_DataPolicyViolations', 'Accessible / helpful',
#        'Preserve / protect', 'Plan town centres', 'Easy to move around',
#        'Drive growth', 'Traffic congestion', 'Revitalised city centre',
#        'Reliable timely transport', 'Public safety',
#        'Visibility of available parking',
#        'Staying informed / provide feedback', '_cachedDate (+00:00 GMT)',
#        '_recordId', '_recordedDate (+00:00 GMT)', '_sourceId', '_sourceMapId',
#        '_sourceType'],
#       dtype='object')
# /Users/ben/PycharmProjects/SurveyVisualisation/venv/lib/python3.12/site-packages/plot_likert/plot_likert.py:257: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(validate)
# /Users/ben/PycharmProjects/SurveyVisualisation/venv/lib/python3.12/site-packages/plot_likert/plot_likert.py:310: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   responses_to_first_question = responses_per_question[0]
# /Users/ben/PycharmProjects/SurveyVisualisation/venv/lib/python3.12/site-packages/plot_likert/plot_likert.py:257: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(validate)
# /Users/ben/PycharmProjects/SurveyVisualisation/venv/lib/python3.12/site-packages/plot_likert/plot_likert.py:310: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   responses_to_first_question = responses_per_question[0]
# /Users/ben/PycharmProjects/SurveyVisualisation/venv/lib/python3.12/site-packages/plot_likert/plot_likert.py:257: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(validate)
# /Users/ben/PycharmProjects/SurveyVisualisation/venv/lib/python3.12/site-packages/plot_likert/plot_likert.py:310: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   responses_to_first_question = responses_per_question[0]
# /Users/ben/PycharmProjects/SurveyVisualisation/venv/lib/python3.12/site-packages/plot_likert/plot_likert.py:257: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(validate)
# /Users/ben/PycharmProjects/SurveyVisualisation/venv/lib/python3.12/site-packages/plot_likert/plot_likert.py:310: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   responses_to_first_question = responses_per_question[0]
# /Users/ben/PycharmProjects/SurveyVisualisation/venv/lib/python3.12/site-packages/plot_likert/plot_likert.py:257: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(validate)
# /Users/ben/PycharmProjects/SurveyVisualisation/venv/lib/python3.12/site-packages/plot_likert/plot_likert.py:310: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   responses_to_first_question = responses_per_question[0]
